# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Download NLTK resources (if not already downloaded)
nltk.download('punkt')
nltk.download('vader_lexicon')
nltk.download('stopwords')

# Sample text for sentiment analysis
text = "I love this product! It's amazing. The quality is great."

# Tokenize sentences
sentences = sent_tokenize(text)

# Initialize list to store filtered sentences
filtered_sentences = []

# Tokenize words and remove stopwords for each sentence
for sentence in sentences:
    tokens = word_tokenize(sentence)
    stop_words = set(stopwords.words('english'))
    filtered_tokens = [word for word in tokens if word.lower() not in stop_words]
    filtered_sentence = ' '.join(filtered_tokens)
    filtered_sentences.append(filtered_sentence)

# Join filtered sentences back into a single string
filtered_text = ' '.join(filtered_sentences)

# Initialize Sentiment Intensity Analyzer
sid = SentimentIntensityAnalyzer()

# Perform sentiment analysis
scores = sid.polarity_scores(filtered_text)

# Print sentiment scores
print("Sentiment Scores:", scores)

# Generate word cloud based on the filtered text
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(filtered_text)

# Display word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud for Sentiment Analysis (with Stopwords Removal)')
plt.show()

# Print filtered sentences
print("\nFiltered Sentences:")
for idx, sentence in enumerate(filtered_sentences, start=1):
    print(f"Sentence {idx}: {sentence}")
# Out:
# [nltk_data] Downloading package punkt to C:\Users\SIVABALAJI
# [nltk_data]     S\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to C:\Users\SIVABALAJI
# [nltk_data]     S\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\SIVABALAJI
# [nltk_data]     S\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Sentiment Scores: {'neg': 0.0, 'neu': 0.195, 'pos': 0.805, 'compound': 0.9245}
# Filtered Sentences:
# Sentence 1: love product !
# Sentence 2: 's amazing .
# Sentence 3: quality great .

# %%
print(stop_words)
# Out:
# {"mightn't", 'doesn', 'wasn', "you'll", 'each', 'now', 'but', 'didn', 'had', 'mightn', 'same', 'hadn', 'am', 'he', "she's", 'weren', 'my', 'again', 'on', 'you', 'can', 'above', 'while', 'an', 'isn', 'whom', 'did', "hasn't", "weren't", "shouldn't", 'hasn', 'his', 'do', 'from', 'which', 'what', 'doing', 'they', 'up', 'being', "didn't", 'most', 'during', 'by', 'off', 'be', 'then', 'should', 'all', 'with', 're', 'myself', 'has', "won't", 'a', 'further', 'ours', 'under', "shan't", 'yours', 'does', 'been', 'that', 'were', "that'll", 'themselves', 'about', 'for', 'herself', 'to', 'it', 've', 'more', 'as', 'itself', 'some', "mustn't", 'mustn', 'll', 'have', 'y', 'why', 'i', 'how', 'through', 'them', 'into', 'this', 'hers', 'was', "aren't", 'needn', 'in', 'only', 'or', 'shouldn', 'because', 'don', 'few', 'than', 'against', 'its', 'yourself', 'too', 'd', 's', 'haven', 'those', 'very', "wouldn't", "hadn't", 'such', "doesn't", 'after', 'where', 'once', 'and', 'won', 'of', "should've", "you'd", '
# ...

# %%
print(filtered_sentences)
# Out:
# ['love product !', "'s amazing .", 'quality great .']
